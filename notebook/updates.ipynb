# %% [markdown]
# # Update documents and Collections

# %%
from connect import db
from pymongo import UpdateOne

modificar = db.libros

# Usando Update estoy agregando 10 libros al stock
res = modificar.update_one(
    {'Titulo': 'La Ciudad Verde'},
    {'$inc':{
        'Stock': 10 }
    }
)
print ('Cambios', res.matched_count, 'Total', res.modified_count)
# Out:
# Cambios 1 Total 1

# %%
for doc in modificar.find({'Titulo': 'La Ciudad Verde'}):
    print(doc['Titulo'], 'Hay', doc['Stock'], 'libros')
# Out:
# La Ciudad Verde Hay 14 libros

# %%
# Actualización de Stock actual
res = modificar.update_one(
    {'Titulo': 'La Ciudad Verde'},
    {'$set':{'Stock': 4 }}
)
print ('Cambios', res.matched_count, 'Total', res.modified_count)
# Out:
# Cambios 1 Total 1

# %%
for doc in modificar.find({'Titulo': 'La Ciudad Verde'}):
    print(doc['Titulo'], 'Hay', doc['Stock'], 'libros')
# Out:
# La Ciudad Verde Hay 4 libros

# %%
# Actualización usando Update Many
res2 = modificar.update_many(
    {},
    {'$set':{
        'disponible' : True
        }
    }
)
print ('Cambios', res2.matched_count, 'Total', res2.modified_count)
# Out:
# Cambios 23 Total 23

# %%
for doc in modificar.find({'disponible': True}):
    print('Disponible', doc['disponible'])
# Out:
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True
# Disponible True

# %%
# Bulk write
operations = [
    UpdateOne({'Titulo':'La Ciudad Verde'}, {'$set': {'Stock': 6}}),   
]
modificar.bulk_write(operations)
# Out:
# BulkWriteResult({'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 1, 'nModified': 1, 'nRemoved': 0, 'upserted': []}, acknowledged=True)
